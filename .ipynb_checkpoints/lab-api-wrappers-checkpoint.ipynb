# %% [markdown]
# <div style='text-align: right;'>
#     bojan.gjokjevski
# </div>
#
# ---
#
# # Lab | API wrappers
# ### Create your collection of songs & audio features
#
# #### Instructions
#
# To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster. The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!
#
# ---

# %%
import pandas as pd
import spotipy

# %%
from pandas import json_normalize
from spotipy.oauth2 import SpotifyClientCredentials
from random import randint
from time import sleep

# %%
secrets_file = open('secrets.txt','r')

# %%
string = secrets_file.read()

# %%
# string

# %%
# string.split('\n')

# %%
secrets_dict = {}

for line in string.split('\n'):
    if len(line) > 0:
#         print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
# secrets_dict

# %%
# initialize SpotiPy with user credentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %% [markdown]
# ### Import songs and artists from playlists

# %%
# function to extract tracks from spotify based on a spotify playlist

def get_playlist_tracks(playlist_id):

    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    
    while results['next']!=None:
        
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    
    return tracks

# %%
# first playlist
tracks1 = get_playlist_tracks("6yPiKpy7evrwvZodByKvM9")

# %%
# second playlist
tracks2 = get_playlist_tracks("4vBaGi0msaCBxhAq9lWXk3")

# %%
type(tracks1)
# Out:
# list

# %%
# playlists length and total number of tracks
print(len(tracks1))
print(len(tracks2))
print('total:',len(tracks1)+len(tracks2))
# Out:
# 10000
# 5633
# total: 15633

# %%
# json_normalizing the data, from list to df
tracks1_df = json_normalize(tracks1)
tracks2_df = json_normalize(tracks2)

# %%
# df for the first playlist
print(tracks1_df.shape)
tracks1_df.head()
# Out:
# (10000, 40)
#                added_at  is_local primary_color  \
# 0  2017-02-27T01:38:09Z     False          None
# 1  2017-02-27T01:38:09Z     False          None
# 2  2017-02-27T01:38:09Z     False          None
# 3  2017-02-27T01:38:09Z     False          None
# 4  2017-02-27T01:38:09Z     False          None
#
#               added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/12160726861
# 1  https://open.spotify.com/user/12160726861
# 2  https://open.spotify.com/user/12160726861
# 3  https://open.spotify.com/user/12160726861
# 4  https://open.spotify.com/user/12160726861
#
#                                   added_by.href  added_by.id added_by.type  \
# 0  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 1  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 2  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 3  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 4  https://api.spotify.com/v1/users/12160726861  12160726861          user
#
#                added_by.uri track.album.album_type  \
# 0  spotify:user:12160726861                  album
# 1  spotify:user:12160726861                  album
# 2  spotify:user:12160726861                  album
# 3  spotify:user:12160726861                  album
# 4  spotify:user:12160726861            compilation
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                  track.id track.is_local        track.name track.popularity  \
# 0  33xMbeHzmWd6Od0BmLZEUs          False                2K                0
# 1  3UnyplmZaq547hwsfOR5yy          False   4 Billion Souls               24
# 2  1w8QCSDH4QobcQeT4uMKLm          False  4 Minute Warning                0
# 3  7J9mBHG4J2eIfDAv5BehKA          False         7 Element                0
# 4  1VZedwJj1gyi88WFRhfThb          False          #9 Dream                5
#
#                                    track.preview_url track.track  \
# 0                                               None        True
# 1  https://p.scdn.co/mp3-preview/d6645e0eeb0f6849...        True
# 2                                               None        True
# 3                                               None        True
# 4  https://p.scdn.co/mp3-preview/1902adb4d960b913...        True
#
#   track.track_number track.type                             track.uri  \
# 0                 17      track  spotify:track:33xMbeHzmWd6Od0BmLZEUs
# 1                  2      track  spotify:track:3UnyplmZaq547hwsfOR5yy
# 2                  8      track  spotify:track:1w8QCSDH4QobcQeT4uMKLm
# 3                  2      track  spotify:track:7J9mBHG4J2eIfDAv5BehKA
# 4                 47      track  spotify:track:1VZedwJj1gyi88WFRhfThb
#
#   video_thumbnail.url
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
#
# [5 rows x 40 columns]

# %%
# df for the second playlist
print(tracks2_df.shape)
tracks2_df.head()
# Out:
# (5633, 40)
#                added_at  is_local primary_color  \
# 0  2014-07-28T00:20:28Z     False          None
# 1  2014-09-19T22:14:40Z     False          None
# 2  2018-10-18T05:20:13Z     False          None
# 3  2018-10-18T05:20:48Z     False          None
# 4  2018-10-18T05:20:50Z     False          None
#
#             added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/larrypeay
# 1  https://open.spotify.com/user/larrypeay
# 2  https://open.spotify.com/user/larrypeay
# 3  https://open.spotify.com/user/larrypeay
# 4  https://open.spotify.com/user/larrypeay
#
#                                 added_by.href added_by.id added_by.type  \
# 0  https://api.spotify.com/v1/users/larrypeay   larrypeay          user
# 1  https://api.spotify.com/v1/users/larrypeay   larrypeay          user
# 2  https://api.spotify.com/v1/users/larrypeay   larrypeay          user
# 3  https://api.spotify.com/v1/users/larrypeay   larrypeay          user
# 4  https://api.spotify.com/v1/users/larrypeay   larrypeay          user
#
#              added_by.uri track.album.album_type  \
# 0  spotify:user:larrypeay                  album
# 1  spotify:user:larrypeay                  album
# 2  spotify:user:larrypeay                  album
# 3  spotify:user:larrypeay                  album
# 4  spotify:user:larrypeay                  album
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                  track.id track.is_local  \
# 0  7dmLg6dYLmjlJXNwFEPQqf          False
# 1  3QcuZo6WLcFkqqLmDs0d95          False
# 2  1KHdq8NK9QxnGjdXb55NiG          False
# 3  40h65HAR8COEoqkMwUUQHu          False
# 4  3oAWTk92mZBxKBOKf8mR5v          False
#
#                               track.name track.popularity  \
# 0   You're The One - Un mal pour un bien                0
# 1                         Doctor My Eyes               12
# 2       Falling in Love at a Coffee Shop               53
# 3  Peaceful Easy Feeling - 2013 Remaster               70
# 4                       Summertime Blues               63
#
#                                    track.preview_url track.track  \
# 0                                               None        True
# 1                                               None        True
# 2  https://p.scdn.co/mp3-preview/760f873c73d8cacd...        True
# 3  https://p.scdn.co/mp3-preview/2b5b9400d354e0c4...        True
# 4                                               None        True
#
#   track.track_number track.type                             track.uri  \
# 0                  5      track  spotify:track:7dmLg6dYLmjlJXNwFEPQqf
# 1                  4      track  spotify:track:3QcuZo6WLcFkqqLmDs0d95
# 2                  4      track  spotify:track:1KHdq8NK9QxnGjdXb55NiG
# 3                  9      track  spotify:track:40h65HAR8COEoqkMwUUQHu
# 4                  7      track  spotify:track:3oAWTk92mZBxKBOKf8mR5v
#
#   video_thumbnail.url
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
#
# [5 rows x 40 columns]

# %%
# function to extract the data from dict(cell) 'track.artists' and add it into the df as a new column 'song_id'

def expand_list_dict2(row):

    df = json_normalize(row['track.artists'])
    df['song_id'] = row['track.id']
    
    return df

# %%
type(tracks1_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#  applying the fuction on the first df, to extract the data from cells in column track.artists and add them at the end
tracks1_df['artists_dfs'] = tracks1_df.apply(expand_list_dict2, axis=1)

# %%
tracks1_df['artists_dfs'][3]
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/0UK6JkgUMa2...  0UK6JkgUMa28b4t8eCtg6P
#
#     name    type                                    uri  \
# 0  Vitas  artist  spotify:artist:0UK6JkgUMa28b4t8eCtg6P
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/0UK6JkgUMa28b4...  7J9mBHG4J2eIfDAv5BehKA

# %%
# applying the fuction on the second df, to extract the data from cells in column track.artists and add them at the end
tracks2_df['artists_dfs'] = tracks2_df.apply(expand_list_dict2, axis=1)
tracks2_df['artists_dfs'][7]
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/09C0xjtosNA...  09C0xjtosNAIXP36wTnWxd
#
#           name    type                                    uri  \
# 0  Fats Domino  artist  spotify:artist:09C0xjtosNAIXP36wTnWxd
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/09C0xjtosNAIXP...  4ZfQwNx3FlCN07cnUvekh3

# %%
artist1_df = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri'])
artist2_df = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri'])

# %%
for mini_df in tracks1_df['artists_dfs']:
    artist1_df = pd.concat([artist1_df, mini_df], axis=0)
    
artist1_df
# Out:
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/artists/0IVapwlnM3d...  0IVapwlnM3dEOiMsHXsghT
# 0   https://api.spotify.com/v1/artists/22WZ7M8sxp5...  22WZ7M8sxp5THdruNY3gXt
# 0   https://api.spotify.com/v1/artists/4Z8W4fKeB5Y...  4Z8W4fKeB5YxbusRsdQVPb
# 0   https://api.spotify.com/v1/artists/0UK6JkgUMa2...  0UK6JkgUMa28b4t8eCtg6P
# 0   https://api.spotify.com/v1/artists/4KWTAlx2Rvb...  4KWTAlx2RvbpseOGMEmROg
# ..                                                ...                     ...
# 0   https://api.spotify.com/v1/artists/3RGLhK1IP9j...  3RGLhK1IP9jnYFH4BRFJBS
# 0   https://api.spotify.com/v1/artists/3ICyfoySNDZ...  3ICyfoySNDZqtBVmaBT84I
# 0   https://api.spotify.com/v1/artists/3OsRAKCvk37...  3OsRAKCvk37zwYcnzRf5XF
# 0   https://api.spotify.com/v1/artists/023YMawCG3O...  023YMawCG3OvACmRjWxLWC
# 0   https://api.spotify.com/v1/artists/2pH3wEn4eYl...  2pH3wEn4eYlMMIIQyKPbVR
#
#               name    type                                    uri  \
# 0      Nosaj Thing  artist  spotify:artist:0IVapwlnM3dEOiMsHXsghT
# 0        The Doors  artist  spotify:artist:22WZ7M8sxp5THdruNY3gXt
# 0        Radiohead  artist  spotify:artist:4Z8W4fKeB5YxbusRsdQVPb
# 0            Vitas  artist  spotify:artist:0UK6JkgUMa28b4t8eCtg6P
# 0           R.E.M.  artist  spotify:artist:4KWTAlx2RvbpseOGMEmROg
# ..             ...     ...                                    ...
# 0        The Clash  artist  spotify:artist:3RGLhK1IP9jnYFH4BRFJBS
# 0              War  artist  spotify:artist:3ICyfoySNDZqtBVmaBT84I
# 0             Moby  artist  spotify:artist:3OsRAKCvk37zwYcnzRf5XF
# 0   The Cat Empire  artist  spotify:artist:023YMawCG3OvACmRjWxLWC
# 0      DragonForce  artist  spotify:artist:2pH3wEn4eYlMMIIQyKPbVR
#
#                                 external_urls.spotify                 song_id
# 0   https://open.spotify.com/artist/0IVapwlnM3dEOi...  33xMbeHzmWd6Od0BmLZEUs
# 0   https://open.spotify.com/artist/22WZ7M8sxp5THd...  3UnyplmZaq547hwsfOR5yy
# 0   https://open.spotify.com/artist/4Z8W4fKeB5Yxbu...  1w8QCSDH4QobcQeT4uMKLm
# 0   https://open.spotify.com/artist/0UK6JkgUMa28b4...  7J9mBHG4J2eIfDAv5BehKA
# 0   https://open.spotify.com/artist/4KWTAlx2Rvbpse...  1VZedwJj1gyi88WFRhfThb
# ..                                                ...                     ...
# 0   https://open.spotify.com/artist/3RGLhK1IP9jnYF...  5jzma6gCzYtKB1DbEwFZKH
# 0   https://open.spotify.com/artist/3ICyfoySNDZqtB...  2fmMPJb5EzZCx8BcNJvVk4
# 0   https://open.spotify.com/artist/3OsRAKCvk37zwY...  60rIdEPDrzyLiLC0icp3xz
# 0   https://open.spotify.com/artist/023YMawCG3OvAC...  0sEm1ld0V8YTCPcjPVfIsc
# 0   https://open.spotify.com/artist/2pH3wEn4eYlMMI...  4JPE3Q7vuFa6UFoduMgZm2
#
# [11853 rows x 7 columns]

# %%
for mini_df in tracks2_df['artists_dfs']:
    artist2_df = pd.concat([artist2_df, mini_df], axis=0)
    
artist2_df
# Out:
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/artists/6nKqt1nbSBE...  6nKqt1nbSBEq3iUXD1Xgz8
# 0   https://api.spotify.com/v1/artists/5lkiCO9UQ8B...  5lkiCO9UQ8B23dZ1o0UV4m
# 0   https://api.spotify.com/v1/artists/1whjlG0NSaQ...  1whjlG0NSaQytgDIWz10GS
# 0   https://api.spotify.com/v1/artists/0ECwFtbIWEV...  0ECwFtbIWEVNwjlrfc6xoL
# 0   https://api.spotify.com/v1/artists/1p0t3JtUTay...  1p0t3JtUTayV2wb1RGN9mO
# ..                                                ...                     ...
# 0   https://api.spotify.com/v1/artists/69g2TelswPN...  69g2TelswPN1IiFDKvaoSL
# 0   https://api.spotify.com/v1/artists/36eDX6PQlJk...  36eDX6PQlJkjxXUhIINO5w
# 0   https://api.spotify.com/v1/artists/3ahRanZQnsZ...  3ahRanZQnsZmAVMNqRsimM
# 0   https://api.spotify.com/v1/artists/1eEfMU2AhEo...  1eEfMU2AhEo7XnKgL7c304
# 0   https://api.spotify.com/v1/artists/6v8FB84lnmJ...  6v8FB84lnmJs434UJf2Mrm
#
#                      name    type                                    uri  \
# 0            Petula Clark  artist  spotify:artist:6nKqt1nbSBEq3iUXD1Xgz8
# 0          Jackson Browne  artist  spotify:artist:5lkiCO9UQ8B23dZ1o0UV4m
# 0             Landon Pigg  artist  spotify:artist:1whjlG0NSaQytgDIWz10GS
# 0                  Eagles  artist  spotify:artist:0ECwFtbIWEVNwjlrfc6xoL
# 0           Eddie Cochran  artist  spotify:artist:1p0t3JtUTayV2wb1RGN9mO
# ..                    ...     ...                                    ...
# 0   Chairmen Of The Board  artist  spotify:artist:69g2TelswPN1IiFDKvaoSL
# 0    Jay & The Techniques  artist  spotify:artist:36eDX6PQlJkjxXUhIINO5w
# 0             The Ad Libs  artist  spotify:artist:3ahRanZQnsZmAVMNqRsimM
# 0              Carpenters  artist  spotify:artist:1eEfMU2AhEo7XnKgL7c304
# 0              Neil Young  artist  spotify:artist:6v8FB84lnmJs434UJf2Mrm
#
#                                 external_urls.spotify                 song_id
# 0   https://open.spotify.com/artist/6nKqt1nbSBEq3i...  7dmLg6dYLmjlJXNwFEPQqf
# 0   https://open.spotify.com/artist/5lkiCO9UQ8B23d...  3QcuZo6WLcFkqqLmDs0d95
# 0   https://open.spotify.com/artist/1whjlG0NSaQytg...  1KHdq8NK9QxnGjdXb55NiG
# 0   https://open.spotify.com/artist/0ECwFtbIWEVNwj...  40h65HAR8COEoqkMwUUQHu
# 0   https://open.spotify.com/artist/1p0t3JtUTayV2w...  3oAWTk92mZBxKBOKf8mR5v
# ..                                                ...                     ...
# 0   https://open.spotify.com/artist/69g2TelswPN1Ii...  6qbtTps7ZebLrWtqtu1joj
# 0   https://open.spotify.com/artist/36eDX6PQlJkjxX...  1m1UTLYGCzEciEdSfpK1Yu
# 0   https://open.spotify.com/artist/3ahRanZQnsZmAV...  3kOrjPYYNLlWp7RJlzyg66
# 0   https://open.spotify.com/artist/1eEfMU2AhEo7Xn...  0OFUUZdNXJ6KP8DvhN6WVN
# 0   https://open.spotify.com/artist/6v8FB84lnmJs43...  2y3Ek8naO0FJgNaddG12TU
#
# [5892 rows x 7 columns]

# %%
df1_merged = pd.merge(left=tracks1_df,
                      right=artist1_df,
                      how='inner',
                      left_on='track.id',
                      right_on='song_id')
df1_merged.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2017-02-27T01:38:09Z     False          None
# 1  2017-02-27T01:38:09Z     False          None
# 2  2017-02-27T01:38:09Z     False          None
# 3  2017-02-27T01:38:09Z     False          None
# 4  2017-02-27T01:38:09Z     False          None
#
#               added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/12160726861
# 1  https://open.spotify.com/user/12160726861
# 2  https://open.spotify.com/user/12160726861
# 3  https://open.spotify.com/user/12160726861
# 4  https://open.spotify.com/user/12160726861
#
#                                   added_by.href  added_by.id added_by.type  \
# 0  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 1  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 2  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 3  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 4  https://api.spotify.com/v1/users/12160726861  12160726861          user
#
#                added_by.uri track.album.album_type  \
# 0  spotify:user:12160726861                  album
# 1  spotify:user:12160726861                  album
# 2  spotify:user:12160726861                  album
# 3  spotify:user:12160726861                  album
# 4  spotify:user:12160726861            compilation
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                               track.uri video_thumbnail.url  \
# 0  spotify:track:33xMbeHzmWd6Od0BmLZEUs                None
# 1  spotify:track:3UnyplmZaq547hwsfOR5yy                None
# 2  spotify:track:1w8QCSDH4QobcQeT4uMKLm                None
# 3  spotify:track:7J9mBHG4J2eIfDAv5BehKA                None
# 4  spotify:track:1VZedwJj1gyi88WFRhfThb                None
#
#                                          artists_dfs  \
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/0IVapwlnM3d...  0IVapwlnM3dEOiMsHXsghT
# 1  https://api.spotify.com/v1/artists/22WZ7M8sxp5...  22WZ7M8sxp5THdruNY3gXt
# 2  https://api.spotify.com/v1/artists/4Z8W4fKeB5Y...  4Z8W4fKeB5YxbusRsdQVPb
# 3  https://api.spotify.com/v1/artists/0UK6JkgUMa2...  0UK6JkgUMa28b4t8eCtg6P
# 4  https://api.spotify.com/v1/artists/4KWTAlx2Rvb...  4KWTAlx2RvbpseOGMEmROg
#
#           name    type                                    uri  \
# 0  Nosaj Thing  artist  spotify:artist:0IVapwlnM3dEOiMsHXsghT
# 1    The Doors  artist  spotify:artist:22WZ7M8sxp5THdruNY3gXt
# 2    Radiohead  artist  spotify:artist:4Z8W4fKeB5YxbusRsdQVPb
# 3        Vitas  artist  spotify:artist:0UK6JkgUMa28b4t8eCtg6P
# 4       R.E.M.  artist  spotify:artist:4KWTAlx2RvbpseOGMEmROg
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/0IVapwlnM3dEOi...  33xMbeHzmWd6Od0BmLZEUs
# 1  https://open.spotify.com/artist/22WZ7M8sxp5THd...  3UnyplmZaq547hwsfOR5yy
# 2  https://open.spotify.com/artist/4Z8W4fKeB5Yxbu...  1w8QCSDH4QobcQeT4uMKLm
# 3  https://open.spotify.com/artist/0UK6JkgUMa28b4...  7J9mBHG4J2eIfDAv5BehKA
# 4  https://open.spotify.com/artist/4KWTAlx2Rvbpse...  1VZedwJj1gyi88WFRhfThb
#
# [5 rows x 48 columns]

# %%
df2_merged = pd.merge(left=tracks2_df,
                      right=artist2_df,
                      how='inner',
                      left_on='track.id',
                      right_on='song_id')
df2_merged.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2014-07-28T00:20:28Z     False          None
# 1  2014-09-19T22:14:40Z     False          None
# 2  2018-10-18T05:20:13Z     False          None
# 3  2018-10-18T05:20:48Z     False          None
# 4  2018-10-18T05:20:50Z     False          None
#
#             added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/larrypeay
# 1  https://open.spotify.com/user/larrypeay
# 2  https://open.spotify.com/user/larrypeay
# 3  https://open.spotify.com/user/larrypeay
# 4  https://open.spotify.com/user/larrypeay
#
#                                 added_by.href added_by.id added_by.type  \
# 0  https://api.spotify.com/v1/users/larrypeay   larrypeay          user
# 1  https://api.spotify.com/v1/users/larrypeay   larrypeay          user
# 2  https://api.spotify.com/v1/users/larrypeay   larrypeay          user
# 3  https://api.spotify.com/v1/users/larrypeay   larrypeay          user
# 4  https://api.spotify.com/v1/users/larrypeay   larrypeay          user
#
#              added_by.uri track.album.album_type  \
# 0  spotify:user:larrypeay                  album
# 1  spotify:user:larrypeay                  album
# 2  spotify:user:larrypeay                  album
# 3  spotify:user:larrypeay                  album
# 4  spotify:user:larrypeay                  album
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                               track.uri video_thumbnail.url  \
# 0  spotify:track:7dmLg6dYLmjlJXNwFEPQqf                None
# 1  spotify:track:3QcuZo6WLcFkqqLmDs0d95                None
# 2  spotify:track:1KHdq8NK9QxnGjdXb55NiG                None
# 3  spotify:track:40h65HAR8COEoqkMwUUQHu                None
# 4  spotify:track:3oAWTk92mZBxKBOKf8mR5v                None
#
#                                          artists_dfs  \
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/6nKqt1nbSBE...  6nKqt1nbSBEq3iUXD1Xgz8
# 1  https://api.spotify.com/v1/artists/5lkiCO9UQ8B...  5lkiCO9UQ8B23dZ1o0UV4m
# 2  https://api.spotify.com/v1/artists/1whjlG0NSaQ...  1whjlG0NSaQytgDIWz10GS
# 3  https://api.spotify.com/v1/artists/0ECwFtbIWEV...  0ECwFtbIWEVNwjlrfc6xoL
# 4  https://api.spotify.com/v1/artists/1p0t3JtUTay...  1p0t3JtUTayV2wb1RGN9mO
#
#              name    type                                    uri  \
# 0    Petula Clark  artist  spotify:artist:6nKqt1nbSBEq3iUXD1Xgz8
# 1  Jackson Browne  artist  spotify:artist:5lkiCO9UQ8B23dZ1o0UV4m
# 2     Landon Pigg  artist  spotify:artist:1whjlG0NSaQytgDIWz10GS
# 3          Eagles  artist  spotify:artist:0ECwFtbIWEVNwjlrfc6xoL
# 4   Eddie Cochran  artist  spotify:artist:1p0t3JtUTayV2wb1RGN9mO
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/6nKqt1nbSBEq3i...  7dmLg6dYLmjlJXNwFEPQqf
# 1  https://open.spotify.com/artist/5lkiCO9UQ8B23d...  3QcuZo6WLcFkqqLmDs0d95
# 2  https://open.spotify.com/artist/1whjlG0NSaQytg...  1KHdq8NK9QxnGjdXb55NiG
# 3  https://open.spotify.com/artist/0ECwFtbIWEVNwj...  40h65HAR8COEoqkMwUUQHu
# 4  https://open.spotify.com/artist/1p0t3JtUTayV2w...  3oAWTk92mZBxKBOKf8mR5v
#
# [5 rows x 48 columns]

# %%
df = pd.concat([df1_merged, df2_merged], axis=0)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_final = df[['track.name', 'name', 'song_id']]

# %%
df_final.duplicated().value_counts()
# Out:
# False    17739
# True      6748
# Name: count, dtype: int64

# %%
df_final = df_final.drop_duplicates(keep='first', ignore_index=True)

# %%
df_final
# Out:
#                             track.name                   name  \
# 0                                   2K            Nosaj Thing
# 1                      4 Billion Souls              The Doors
# 2                     4 Minute Warning              Radiohead
# 3                            7 Element                  Vitas
# 4                             #9 Dream                 R.E.M.
# ...                                ...                    ...
# 17734  Give Me Just A Little More Time  Chairmen Of The Board
# 17735     Apples, Peaches, Pumpkin Pie   Jay & The Techniques
# 17736       The Boy From New York City            The Ad Libs
# 17737                     Intermission             Carpenters
# 17738                         Helpless             Neil Young
#
#                       song_id
# 0      33xMbeHzmWd6Od0BmLZEUs
# 1      3UnyplmZaq547hwsfOR5yy
# 2      1w8QCSDH4QobcQeT4uMKLm
# 3      7J9mBHG4J2eIfDAv5BehKA
# 4      1VZedwJj1gyi88WFRhfThb
# ...                       ...
# 17734  6qbtTps7ZebLrWtqtu1joj
# 17735  1m1UTLYGCzEciEdSfpK1Yu
# 17736  3kOrjPYYNLlWp7RJlzyg66
# 17737  0OFUUZdNXJ6KP8DvhN6WVN
# 17738  2y3Ek8naO0FJgNaddG12TU
#
# [17739 rows x 3 columns]

# %%
df_final['track.name'].duplicated().value_counts()
# Out:
# track.name
# False    13363
# True      4376
# Name: count, dtype: int64

# %%
df_final['name'].duplicated().value_counts()
# Out:
# name
# True     12580
# False     5159
# Name: count, dtype: int64

# %%
df_final['song_id'].duplicated().value_counts()
# Out:
# song_id
# False    15078
# True      2661
# Name: count, dtype: int64

# %%
df_final.dropna(axis=0, subset='song_id', inplace=True)

# %%
# checking audio_features for a certain song 
sp.audio_features('33xMbeHzmWd6Od0BmLZEUs')
# Out:
# [{'danceability': 0.31,
#   'energy': 0.445,
#   'key': 7,
#   'loudness': -13.355,
#   'mode': 0,
#   'speechiness': 0.0863,
#   'acousticness': 0.094,
#   'instrumentalness': 0.0678,
#   'liveness': 0.113,
#   'valence': 0.122,
#   'tempo': 95.36,
#   'type': 'audio_features',
#   'id': '33xMbeHzmWd6Od0BmLZEUs',
#   'uri': 'spotify:track:33xMbeHzmWd6Od0BmLZEUs',
#   'track_href': 'https://api.spotify.com/v1/tracks/33xMbeHzmWd6Od0BmLZEUs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/33xMbeHzmWd6Od0BmLZEUs',
#   'duration_ms': 152560,
#   'time_signature': 3}]

# %%
chunks = [(i, i+100) for i in range(0, len(df_final), 100)]
# chunks

# %%
audio_features_list = []

# %%
# extractig audio features from spotify through chunks of id's stored in a list, for all song in total

for chunk in chunks:
    
    id_list100 = df_final['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
    
len(audio_features_list)
# Out:
# 17172

# %%
audio_features_df = json_normalize(audio_features_list)

# %%
audio_features_df.drop_duplicates(inplace=True) # duplicates because some songs have more artists

# %%
songs_audiof_df = pd.merge(left=df_final,
                           right=audio_features_df,
                           how='inner',
                           left_on='song_id',
                           right_on='id')

# %%
# combined df with songs, artists and audio features for everysong
songs_audiof_df
# Out:
#                             track.name                   name  \
# 0                                   2K            Nosaj Thing
# 1                      4 Billion Souls              The Doors
# 2                     4 Minute Warning              Radiohead
# 3                            7 Element                  Vitas
# 4                             #9 Dream                 R.E.M.
# ...                                ...                    ...
# 17167  Give Me Just A Little More Time  Chairmen Of The Board
# 17168     Apples, Peaches, Pumpkin Pie   Jay & The Techniques
# 17169       The Boy From New York City            The Ad Libs
# 17170                     Intermission             Carpenters
# 17171                         Helpless             Neil Young
#
#                       song_id  danceability  energy  key  loudness  mode  \
# 0      33xMbeHzmWd6Od0BmLZEUs         0.310  0.4450    7   -13.355     0
# 1      3UnyplmZaq547hwsfOR5yy         0.419  0.5650    5   -11.565     1
# 2      1w8QCSDH4QobcQeT4uMKLm         0.354  0.3020    9   -13.078     1
# 3      7J9mBHG4J2eIfDAv5BehKA         0.727  0.7850    5    -6.707     0
# 4      1VZedwJj1gyi88WFRhfThb         0.571  0.7240    0    -5.967     1
# ...                       ...           ...     ...  ...       ...   ...
# 17167  6qbtTps7ZebLrWtqtu1joj         0.583  0.4570    9   -11.166     0
# 17168  1m1UTLYGCzEciEdSfpK1Yu         0.637  0.7150   10    -8.670     1
# 17169  3kOrjPYYNLlWp7RJlzyg66         0.474  0.8950   11    -5.105     1
# 17170  0OFUUZdNXJ6KP8DvhN6WVN         0.340  0.0605    3   -17.755     1
# 17171  2y3Ek8naO0FJgNaddG12TU         0.507  0.3660    2    -9.958     1
#
#        speechiness  acousticness  ...  liveness  valence    tempo  \
# 0           0.0863        0.0940  ...    0.1130    0.122   95.360
# 1           0.0347        0.1370  ...    0.1280    0.648  151.277
# 2           0.0326        0.5900  ...    0.1110    0.223  123.753
# 3           0.0603        0.3250  ...    0.3100    0.960  129.649
# 4           0.0260        0.0231  ...    0.0919    0.385  116.755
# ...            ...           ...  ...       ...      ...      ...
# 17167       0.0419        0.0635  ...    0.0716    0.612  126.555
# 17168       0.0404        0.4240  ...    0.1130    0.951  139.500
# 17169       0.0826        0.6880  ...    0.1940    0.845  149.192
# 17170       0.0395        0.9750  ...    0.1920    0.265  117.927
# 17171       0.0316        0.6100  ...    0.4540    0.399  113.537
#
#                  type                      id  \
# 0      audio_features  33xMbeHzmWd6Od0BmLZEUs
# 1      audio_features  3UnyplmZaq547hwsfOR5yy
# 2      audio_features  1w8QCSDH4QobcQeT4uMKLm
# 3      audio_features  7J9mBHG4J2eIfDAv5BehKA
# 4      audio_features  1VZedwJj1gyi88WFRhfThb
# ...               ...                     ...
# 17167  audio_features  6qbtTps7ZebLrWtqtu1joj
# 17168  audio_features  1m1UTLYGCzEciEdSfpK1Yu
# 17169  audio_features  3kOrjPYYNLlWp7RJlzyg66
# 17170  audio_features  0OFUUZdNXJ6KP8DvhN6WVN
# 17171  audio_features  2y3Ek8naO0FJgNaddG12TU
#
#                                         uri  \
# 0      spotify:track:33xMbeHzmWd6Od0BmLZEUs
# 1      spotify:track:3UnyplmZaq547hwsfOR5yy
# 2      spotify:track:1w8QCSDH4QobcQeT4uMKLm
# 3      spotify:track:7J9mBHG4J2eIfDAv5BehKA
# 4      spotify:track:1VZedwJj1gyi88WFRhfThb
# ...                                     ...
# 17167  spotify:track:6qbtTps7ZebLrWtqtu1joj
# 17168  spotify:track:1m1UTLYGCzEciEdSfpK1Yu
# 17169  spotify:track:3kOrjPYYNLlWp7RJlzyg66
# 17170  spotify:track:0OFUUZdNXJ6KP8DvhN6WVN
# 17171  spotify:track:2y3Ek8naO0FJgNaddG12TU
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/33xMbeHzmWd6...
# 1      https://api.spotify.com/v1/tracks/3UnyplmZaq54...
# 2      https://api.spotify.com/v1/tracks/1w8QCSDH4Qob...
# 3      https://api.spotify.com/v1/tracks/7J9mBHG4J2eI...
# 4      https://api.spotify.com/v1/tracks/1VZedwJj1gyi...
# ...                                                  ...
# 17167  https://api.spotify.com/v1/tracks/6qbtTps7ZebL...
# 17168  https://api.spotify.com/v1/tracks/1m1UTLYGCzEc...
# 17169  https://api.spotify.com/v1/tracks/3kOrjPYYNLlW...
# 17170  https://api.spotify.com/v1/tracks/0OFUUZdNXJ6K...
# 17171  https://api.spotify.com/v1/tracks/2y3Ek8naO0FJ...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/33xM...      152560
# 1      https://api.spotify.com/v1/audio-analysis/3Uny...      197707
# 2      https://api.spotify.com/v1/audio-analysis/1w8Q...      244285
# 3      https://api.spotify.com/v1/audio-analysis/7J9m...      249940
# 4      https://api.spotify.com/v1/audio-analysis/1VZe...      278320
# ...                                                  ...         ...
# 17167  https://api.spotify.com/v1/audio-analysis/6qbt...      160240
# 17168  https://api.spotify.com/v1/audio-analysis/1m1U...      148493
# 17169  https://api.spotify.com/v1/audio-analysis/3kOr...      181000
# 17170  https://api.spotify.com/v1/audio-analysis/0OFU...       26960
# 17171  https://api.spotify.com/v1/audio-analysis/2y3E...      218253
#
#        time_signature
# 0                   3
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 17167               4
# 17168               4
# 17169               4
# 17170               4
# 17171               4
#
# [17172 rows x 21 columns]

# %%
# saving the df as .csv in the folder with the notebook 
songs_audiof_df.to_csv('spotify_songs_b.csv', index=False)

# %%
pd.read_csv('spotify_songs_b.csv')
# Out:
#                             track.name                   name  \
# 0                                   2K            Nosaj Thing
# 1                      4 Billion Souls              The Doors
# 2                     4 Minute Warning              Radiohead
# 3                            7 Element                  Vitas
# 4                             #9 Dream                 R.E.M.
# ...                                ...                    ...
# 17167  Give Me Just A Little More Time  Chairmen Of The Board
# 17168     Apples, Peaches, Pumpkin Pie   Jay & The Techniques
# 17169       The Boy From New York City            The Ad Libs
# 17170                     Intermission             Carpenters
# 17171                         Helpless             Neil Young
#
#                       song_id  danceability  energy  key  loudness  mode  \
# 0      33xMbeHzmWd6Od0BmLZEUs         0.310  0.4450    7   -13.355     0
# 1      3UnyplmZaq547hwsfOR5yy         0.419  0.5650    5   -11.565     1
# 2      1w8QCSDH4QobcQeT4uMKLm         0.354  0.3020    9   -13.078     1
# 3      7J9mBHG4J2eIfDAv5BehKA         0.727  0.7850    5    -6.707     0
# 4      1VZedwJj1gyi88WFRhfThb         0.571  0.7240    0    -5.967     1
# ...                       ...           ...     ...  ...       ...   ...
# 17167  6qbtTps7ZebLrWtqtu1joj         0.583  0.4570    9   -11.166     0
# 17168  1m1UTLYGCzEciEdSfpK1Yu         0.637  0.7150   10    -8.670     1
# 17169  3kOrjPYYNLlWp7RJlzyg66         0.474  0.8950   11    -5.105     1
# 17170  0OFUUZdNXJ6KP8DvhN6WVN         0.340  0.0605    3   -17.755     1
# 17171  2y3Ek8naO0FJgNaddG12TU         0.507  0.3660    2    -9.958     1
#
#        speechiness  acousticness  ...  liveness  valence    tempo  \
# 0           0.0863        0.0940  ...    0.1130    0.122   95.360
# 1           0.0347        0.1370  ...    0.1280    0.648  151.277
# 2           0.0326        0.5900  ...    0.1110    0.223  123.753
# 3           0.0603        0.3250  ...    0.3100    0.960  129.649
# 4           0.0260        0.0231  ...    0.0919    0.385  116.755
# ...            ...           ...  ...       ...      ...      ...
# 17167       0.0419        0.0635  ...    0.0716    0.612  126.555
# 17168       0.0404        0.4240  ...    0.1130    0.951  139.500
# 17169       0.0826        0.6880  ...    0.1940    0.845  149.192
# 17170       0.0395        0.9750  ...    0.1920    0.265  117.927
# 17171       0.0316        0.6100  ...    0.4540    0.399  113.537
#
#                  type                      id  \
# 0      audio_features  33xMbeHzmWd6Od0BmLZEUs
# 1      audio_features  3UnyplmZaq547hwsfOR5yy
# 2      audio_features  1w8QCSDH4QobcQeT4uMKLm
# 3      audio_features  7J9mBHG4J2eIfDAv5BehKA
# 4      audio_features  1VZedwJj1gyi88WFRhfThb
# ...               ...                     ...
# 17167  audio_features  6qbtTps7ZebLrWtqtu1joj
# 17168  audio_features  1m1UTLYGCzEciEdSfpK1Yu
# 17169  audio_features  3kOrjPYYNLlWp7RJlzyg66
# 17170  audio_features  0OFUUZdNXJ6KP8DvhN6WVN
# 17171  audio_features  2y3Ek8naO0FJgNaddG12TU
#
#                                         uri  \
# 0      spotify:track:33xMbeHzmWd6Od0BmLZEUs
# 1      spotify:track:3UnyplmZaq547hwsfOR5yy
# 2      spotify:track:1w8QCSDH4QobcQeT4uMKLm
# 3      spotify:track:7J9mBHG4J2eIfDAv5BehKA
# 4      spotify:track:1VZedwJj1gyi88WFRhfThb
# ...                                     ...
# 17167  spotify:track:6qbtTps7ZebLrWtqtu1joj
# 17168  spotify:track:1m1UTLYGCzEciEdSfpK1Yu
# 17169  spotify:track:3kOrjPYYNLlWp7RJlzyg66
# 17170  spotify:track:0OFUUZdNXJ6KP8DvhN6WVN
# 17171  spotify:track:2y3Ek8naO0FJgNaddG12TU
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/33xMbeHzmWd6...
# 1      https://api.spotify.com/v1/tracks/3UnyplmZaq54...
# 2      https://api.spotify.com/v1/tracks/1w8QCSDH4Qob...
# 3      https://api.spotify.com/v1/tracks/7J9mBHG4J2eI...
# 4      https://api.spotify.com/v1/tracks/1VZedwJj1gyi...
# ...                                                  ...
# 17167  https://api.spotify.com/v1/tracks/6qbtTps7ZebL...
# 17168  https://api.spotify.com/v1/tracks/1m1UTLYGCzEc...
# 17169  https://api.spotify.com/v1/tracks/3kOrjPYYNLlW...
# 17170  https://api.spotify.com/v1/tracks/0OFUUZdNXJ6K...
# 17171  https://api.spotify.com/v1/tracks/2y3Ek8naO0FJ...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/33xM...      152560
# 1      https://api.spotify.com/v1/audio-analysis/3Uny...      197707
# 2      https://api.spotify.com/v1/audio-analysis/1w8Q...      244285
# 3      https://api.spotify.com/v1/audio-analysis/7J9m...      249940
# 4      https://api.spotify.com/v1/audio-analysis/1VZe...      278320
# ...                                                  ...         ...
# 17167  https://api.spotify.com/v1/audio-analysis/6qbt...      160240
# 17168  https://api.spotify.com/v1/audio-analysis/1m1U...      148493
# 17169  https://api.spotify.com/v1/audio-analysis/3kOr...      181000
# 17170  https://api.spotify.com/v1/audio-analysis/0OFU...       26960
# 17171  https://api.spotify.com/v1/audio-analysis/2y3E...      218253
#
#        time_signature
# 0                   3
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 17167               4
# 17168               4
# 17169               4
# 17170               4
# 17171               4
#
# [17172 rows x 21 columns]
